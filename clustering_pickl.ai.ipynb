# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
df = pd.read_csv('Dataset - Dataset.csv')

df
# Out:
#      Customer ID  Gender  Age  Income     Occupation Marital Status  \
# 0           C001  Female   23   27275        Student         Single
# 1           C002  Female   18   35579        Student         Single
# 2           C003    Male   45   59347      Homemaker         Single
# 3           C004  Female   19   27105        Student        Married
# 4           C005  Female   45   47566      Homemaker         Single
# ...          ...     ...  ...     ...            ...            ...
# 6995       C6996    Male   62   52159   Professional         Single
# 6996       C6997    Male   56   27406  Self-employed         Single
# 6997       C6998  Female   18   41671  Self-employed        Widowed
# 6998       C6999    Male   52   21359      Executive       Divorced
# 6999       C7000  Female   32   44999     Technician        Widowed
#
#       No. Family Members Home Ownership  Home Value  Years in Current Home  \
# 0                      2            Own      442797                     13
# 1                      3            Own      182090                     17
# 2                      2            Own      973684                     12
# 3                      3            Own       94669                      7
# 4                      4            Own      938493                      7
# ...                  ...            ...         ...                    ...
# 6995                   5            Own      449503                      4
# 6996                   2            Own      804846                     18
# 6997                   4            Own      356720                     12
# 6998                   3            Own      978818                     17
# 6999                   5            Own      166775                      6
#
#       ...  Total Credit Card Balance  Product ID  Products Purchased  \
# 0     ...                      22979        P001            Clothing
# 1     ...                      18890        P002             Jewelry
# 2     ...                      14721        P003             Jewelry
# 3     ...                      21491        P004               Books
# 4     ...                       2842        P005             Jewelry
# ...   ...                        ...         ...                 ...
# 6995  ...                      16224       P6996     Beauty Products
# 6996  ...                       8915       P6997        Outdoor Gear
# 6997  ...                       5717       P6998     Home Appliances
# 6998  ...                       7641       P6999         Electronics
# 6999  ...                      20328       P7000     Home Appliances
#
#       Number of Online Purchases Average Purchase Value Last Purchase Value  \
# 0                              8             142.776953           50.131325
# 1                             16             152.688423           40.423631
# 2                              3             115.261674           88.014050
# 3                              1              48.428081          192.532891
# 4                             13             183.458441          233.079310
# ...                          ...                    ...                 ...
# 6995                          15             101.121872          124.814756
# 6996                           9             165.191947          153.226793
# 6997                          20              46.544462           85.187943
# 6998                           2              98.275850          151.667053
# 6999                          14             118.425279          160.690982
#
#       Days Since Last Purchase  Number of Returns  Total Values of Returns  \
# 0                           29                  1                20.110947
# 1                           66                  4                33.868237
# 2                          131                  4                94.178999
# 3                           50                  5                51.754754
# 4                          171                  3                76.830901
# ...                        ...                ...                      ...
# 6995                        21                  0                56.564169
# 6996                         3                  4                87.086811
# 6997                         6                  0                37.188616
# 6998                        72                  3                46.998330
# 6999                       110                  1                55.199802
#
#       Locations
# 0     Bangalore
# 1         Delhi
# 2        Jaipur
# 3        Nashik
# 4     Bangalore
# ...         ...
# 6995  Bangalore
# 6996       Pune
# 6997     Mumbai
# 6998  Bangalore
# 6999  Bangalore
#
# [7000 rows x 23 columns]

# %%
X = df[['Customer ID','Gender', 'Age','Income','Occupation','Marital Status','No. Family Members','Home Ownership','Home Value','Years in Current Home','Credit Score','Number of Credit Cards','Total Credit Card Limit','Total Credit Card Balance','Product ID','Products Purchased','Number of Online Purchases','Average Purchase Value','Last Purchase Value','Days Since Last Purchase','Number of Returns','Total Values of Returns','Locations']].values


inertia = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X)
    inertia.append(kmeans.inertia_)
plt.plot(range(1, 11), inertia)
plt.title('Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.show()


kmeans = KMeans(n_clusters=5, random_state=42)
y_kmeans = kmeans.fit_predict(X)


plt.scatter(X[y_kmeans == 0, 3], X[y_kmeans == 0, 16], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(X[y_kmeans == 1, 3], X[y_kmeans == 1, 16], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(X[y_kmeans == 2, 3], X[y_kmeans == 2, 16], s = 100, c = 'green', label = 'Cluster 3')
plt.scatter(X[y_kmeans == 3, 3], X[y_kmeans == 3, 16], s = 100, c = 'cyan', label = 'Cluster 4')
plt.scatter(X[y_kmeans == 4, 3], X[y_kmeans == 4, 16], s = 100, c = 'magenta', label = 'Cluster 5')
plt.scatter(kmeans.cluster_centers_[:, 3], kmeans.cluster_centers_[:, 16], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Customer Segmentation')
plt.xlabel('Income')
plt.ylabel('Number of Online Purchases')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 7
#       5 for k in range(1, 11):
#       6     kmeans = KMeans(n_clusters=k, random_state=42)
# ----> 7     kmeans.fit(X)
#       8     inertia.append(kmeans.inertia_)
#       9 plt.plot(range(1, 11), inertia)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\sklearn\cluster\_kmeans.py:1367, in KMeans.fit(self, X, y, sample_weight)
#    1341 def fit(self, X, y=None, sample_weight=None):
#    1342     """Compute k-means clustering.
#    1343
#    1344     Parameters
#    (...)
#    1365         Fitted estimator.
#    1366     """
# -> 1367     X = self._validate_data(
#    1368         X,
#    1369         accept_sparse="csr",
#    1370         dtype=[np.float64, np.float32],
#    1371         order="C",
#    1372         copy=self.copy_x,
#    1373         accept_large_sparse=False,
#    1374     )
#    1376     self._check_params(X)
#    1377     random_state = check_random_state(self.random_state)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\sklearn\base.py:577, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     575     raise ValueError("Validation should be done on X, y or both.")
#     576 elif not no_val_X and no_val_y:
# --> 577     X = check_array(X, input_name="X", **check_params)
#     578     out = X
#     579 elif no_val_X and not no_val_y:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\sklearn\utils\validation.py:856, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     854         array = array.astype(dtype, casting="unsafe", copy=False)
#     855     else:
# --> 856         array = np.asarray(array, order=order, dtype=dtype)
#     857 except ComplexWarning as complex_warning:
#     858     raise ValueError(
#     859         "Complex data not supported\n{}\n".format(array)
#     860     ) from complex_warning
#
# ValueError: could not convert string to float: 'C001'

# %%
print(df.columns)
# Out:
# Index(['Customer ID_C001', 'Customer ID_C002', 'Customer ID_C003',
#        'Customer ID_C004', 'Customer ID_C005', 'Customer ID_C006',
#        'Customer ID_C007', 'Customer ID_C008', 'Customer ID_C009',
#        'Customer ID_C010',
#        ...
#        'Locations_Lucknow', 'Locations_Ludhiana', 'Locations_Mumbai',
#        'Locations_Nagpur', 'Locations_Nashik', 'Locations_Patna',
#        'Locations_Pune', 'Locations_Surat', 'Locations_Vadodara',
#        'Locations_Visakhapatnam'],
#       dtype='object', length=61407)
